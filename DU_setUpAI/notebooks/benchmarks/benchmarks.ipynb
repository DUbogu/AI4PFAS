# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../..')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

#from src import models
#from src import experimental_setup
experimental_setup.path_prefix = '/../'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 from src import models
#       5 from src import experimental_setup
#       6 experimental_setup.path_prefix = '/../'
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# # Experimental setup

# %%
_benchmarks = {
    'dnn_mordred': {'model': models.DNN_Mordred, 'encoding': 'mordred'},
    'dnn_ecfp': {'model': models.DNN_ECFP, 'encoding': 'ecfp_2048'},
    'rf_mordred': {'model': models.RF, 'encoding': 'mordred'},
    'rf_ecfp': {'model': models.RF, 'encoding': 'ecfp_4096'},
    'rf_nmf_ecfp': {'model': models.RF_NMF_ECFP, 'encoding': 'ecfp_4096'},
    'gp': {'model': models.GP, 'encoding': 'gp'},
    'gcn': {'model': models.GCN, 'encoding': 'smiles'}
}

# benchmarks to train/validate, check _benchmark_dict for options
# run_benchmarks = ['gcn']   # DU - changed  these to get diff models
run_benchmarks = ['dnn_mordred']

# `random` or `stratified`
sampling_type = 'random'

kfold = experimental_setup.CrossValidator(
    splits = 5, # dont change without re-running data preprocessing
    sampling_type = sampling_type,
)

converter = experimental_setup.LD50UnitConverter()

# %% [markdown]
# # Train/predict using benchmark models

# %%
for identity in run_benchmarks:
    benchmark = _benchmarks[identity]
    
    folds = enumerate(kfold.get_folds(benchmark['encoding']))
    
    for fold_no, (train, test) in folds:           
        x_train, y_train, smiles_train = train
        x_test, y_test, smiles_test = test
        
        y_train = experimental_setup.scaler.fit_transform(y_train)
        
        model = _benchmarks[identity]['model']()
        
        # <Gaussian process has special step for selecting parameters based on
        # RF benchmark models for ECFP and Mordred
        if identity == 'gp':
            fn = 'rf_mordred' + str(fold_no) + '_' + sampling_type
            mordred_rf = _benchmarks['rf_mordred']['model']()
            mordred_rf.load_weights('../../data/benchmark-models/chkpts/%s.chkpt' % fn)
            
            fn = 'rf_ecfp' + str(fold_no) + '_' + sampling_type
            ecfp_rf = _benchmarks['rf_ecfp']['model']()
            ecfp_rf.load_weights('../../data/benchmark-models/chkpts/%s.chkpt' % fn)
            
            model.rf_feature_selectors = (mordred_rf, ecfp_rf)
            model.rf_feature_reduce_to = (10, 200)
        # End of special GP step>
        
        model.fit(x_train, y_train)
        
        #save model
        fn = identity + str(fold_no) + '_' + sampling_type
        model.save_weights('../../data/benchmark-models/chkpts/%s.chkpt' % fn)
        
        y_hat = experimental_setup.scaler.inverse_transform(model.predict(x_test))
        
        results = pd.DataFrame({
            'smiles': smiles_test.flatten(),
            'prediction_neglogld50': y_hat.flatten(),
            'prediction_mgkg': converter.convert_to_mgkg(y_hat, smiles_test),
            'prediction_epa': converter.convert_to_epa(y_hat, smiles_test),
            'actual_neglogld50': y_test.flatten(),
            'actual_mgkg': converter.convert_to_mgkg(y_test, smiles_test),
            'actual_epa': converter.convert_to_epa(y_test, smiles_test),
        })
        
        results.to_csv('../../data/benchmark-models/%s_predictions.csv' % fn)
# Out:
# Epoch 1/1000
# c:\Users\3742\anaconda3\envs\ai4pfas\Lib\site-packages\keras\src\layers\layer.py:391: UserWarning: `build()` was called on layer 'dnn__mordred', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 853951.5000 - mae: 249.8174 - mse: 853951.5000
# Epoch 2/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7944 - mae: 0.9589 - mse: 1.7944
# Epoch 3/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0322 - mae: 0.7708 - mse: 1.0322
# Epoch 4/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1392 - mae: 0.7910 - mse: 1.1392
# Epoch 5/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2238 - mae: 0.8149 - mse: 1.2238
# Epoch 6/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1454 - mae: 0.7927 - mse: 1.1454
# Epoch 7/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1088 - mae: 0.7810 - mse: 1.1088
# Epoch 8/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0575 - mae: 0.7651 - mse: 1.0575
# Epoch 9/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0982 - mae: 0.7778 - mse: 1.0982
# Epoch 10/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1090 - mae: 0.7832 - mse: 1.1090
# Epoch 11/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0877 - mae: 0.7774 - mse: 1.0877
# Epoch 12/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9605 - mae: 0.7367 - mse: 0.9605
# Epoch 13/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8980 - mae: 0.7151 - mse: 0.8980
# Epoch 14/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9860 - mae: 0.7407 - mse: 0.9860
# Epoch 15/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0242 - mae: 0.7560 - mse: 1.0242
# Epoch 16/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0161 - mae: 0.7549 - mse: 1.0161
# Epoch 17/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9057 - mae: 0.7222 - mse: 0.9057
# Epoch 18/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8579 - mae: 0.7023 - mse: 0.8579
# Epoch 19/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9024 - mae: 0.7130 - mse: 0.9024
# Epoch 20/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9187 - mae: 0.7192 - mse: 0.9187
# Epoch 21/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8796 - mae: 0.7068 - mse: 0.8796
# Epoch 22/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8651 - mae: 0.7012 - mse: 0.8651
# Epoch 23/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8642 - mae: 0.7005 - mse: 0.8642
# Epoch 24/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8841 - mae: 0.7068 - mse: 0.8841
# Epoch 25/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9096 - mae: 0.7157 - mse: 0.9096
# Epoch 26/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1061 - mae: 0.7837 - mse: 1.1061
# Epoch 27/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8821 - mae: 0.7142 - mse: 0.8821
# Epoch 28/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8281 - mae: 0.6890 - mse: 0.8281
# Epoch 29/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8388 - mae: 0.6915 - mse: 0.8388
# Epoch 30/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8494 - mae: 0.6943 - mse: 0.8494
# Epoch 31/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8477 - mae: 0.6945 - mse: 0.8477
# Epoch 32/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8412 - mae: 0.6914 - mse: 0.8412
# Epoch 33/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8364 - mae: 0.6894 - mse: 0.8364
# Epoch 34/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8281 - mae: 0.6868 - mse: 0.8281
# Epoch 35/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8268 - mae: 0.6874 - mse: 0.8268
# Epoch 36/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8275 - mae: 0.6884 - mse: 0.8275
# Epoch 37/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8359 - mae: 0.6923 - mse: 0.8359
# Epoch 38/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8459 - mae: 0.6993 - mse: 0.8459
# Epoch 39/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8409 - mae: 0.6900 - mse: 0.8409
# Epoch 40/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8129 - mae: 0.6833 - mse: 0.8129
# Epoch 41/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8662 - mae: 0.7044 - mse: 0.8662
# Epoch 42/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9013 - mae: 0.7185 - mse: 0.9013
# Epoch 43/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9639 - mae: 0.7408 - mse: 0.9639
# Epoch 44/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8525 - mae: 0.6930 - mse: 0.8525
# Epoch 45/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8137 - mae: 0.6846 - mse: 0.8137
# Epoch 46/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8145 - mae: 0.6868 - mse: 0.8145
# Epoch 47/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8349 - mae: 0.6937 - mse: 0.8349
# Epoch 48/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8299 - mae: 0.6844 - mse: 0.8299
# Epoch 49/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7777 - mae: 0.6670 - mse: 0.7777
# Epoch 50/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7705 - mae: 0.6637 - mse: 0.7705
# Epoch 51/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7681 - mae: 0.6627 - mse: 0.7681
# Epoch 52/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7640 - mae: 0.6611 - mse: 0.7640
# Epoch 53/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7632 - mae: 0.6598 - mse: 0.7632
# Epoch 54/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7599 - mae: 0.6601 - mse: 0.7599
# Epoch 55/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7561 - mae: 0.6580 - mse: 0.7561
# Epoch 56/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7538 - mae: 0.6562 - mse: 0.7538
# Epoch 57/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7490 - mae: 0.6552 - mse: 0.7490
# Epoch 58/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7508 - mae: 0.6549 - mse: 0.7508
# Epoch 59/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7440 - mae: 0.6531 - mse: 0.7440
# Epoch 60/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7440 - mae: 0.6531 - mse: 0.7440
# Epoch 61/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7411 - mae: 0.6528 - mse: 0.7411
# Epoch 62/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7437 - mae: 0.6532 - mse: 0.7437
# Epoch 63/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7390 - mae: 0.6520 - mse: 0.7390
# Epoch 64/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7429 - mae: 0.6541 - mse: 0.7429
# Epoch 65/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7354 - mae: 0.6502 - mse: 0.7354
# Epoch 66/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7389 - mae: 0.6527 - mse: 0.7389
# Epoch 67/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7378 - mae: 0.6523 - mse: 0.7378
# Epoch 68/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7266 - mae: 0.6479 - mse: 0.7266
# Epoch 69/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7129 - mae: 0.6414 - mse: 0.7129
# Epoch 70/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7021 - mae: 0.6382 - mse: 0.7021
# Epoch 71/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6993 - mae: 0.6368 - mse: 0.6993
# Epoch 72/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6975 - mae: 0.6357 - mse: 0.6975
# Epoch 73/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.7023 - mae: 0.6366 - mse: 0.7023
# Epoch 74/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6956 - mae: 0.6337 - mse: 0.6956
# Epoch 75/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6963 - mae: 0.6342 - mse: 0.6963
# Epoch 76/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6917 - mae: 0.6307 - mse: 0.6917
# Epoch 77/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6815 - mae: 0.6276 - mse: 0.6815
# Epoch 78/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6746 - mae: 0.6231 - mse: 0.6746
# Epoch 79/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6765 - mae: 0.6235 - mse: 0.6765
# Epoch 80/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6709 - mae: 0.6211 - mse: 0.6709
# Epoch 81/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6761 - mae: 0.6224 - mse: 0.6761
# Epoch 82/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6695 - mae: 0.6194 - mse: 0.6695
# Epoch 83/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6705 - mae: 0.6196 - mse: 0.6705
# Epoch 84/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6677 - mae: 0.6200 - mse: 0.6677
# Epoch 85/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6545 - mae: 0.6142 - mse: 0.6545
# Epoch 86/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6463 - mae: 0.6088 - mse: 0.6463
# Epoch 87/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6531 - mae: 0.6115 - mse: 0.6531
# Epoch 88/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6486 - mae: 0.6121 - mse: 0.6486
# Epoch 89/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6434 - mae: 0.6079 - mse: 0.6434
# Epoch 90/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6368 - mae: 0.6065 - mse: 0.6368
# Epoch 91/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6410 - mae: 0.6074 - mse: 0.6410
# Epoch 92/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6439 - mae: 0.6094 - mse: 0.6439
# Epoch 93/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6336 - mae: 0.6031 - mse: 0.6336
# Epoch 94/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6269 - mae: 0.6031 - mse: 0.6269
# Epoch 95/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6275 - mae: 0.6020 - mse: 0.6275
# Epoch 96/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6241 - mae: 0.6009 - mse: 0.6241
# Epoch 97/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6269 - mae: 0.6022 - mse: 0.6269
# Epoch 98/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6091 - mae: 0.5931 - mse: 0.6091
# Epoch 99/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6227 - mae: 0.5993 - mse: 0.6227
# Epoch 100/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6145 - mae: 0.5956 - mse: 0.6145
# Epoch 101/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6240 - mae: 0.6009 - mse: 0.6240
# Epoch 102/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6237 - mae: 0.5991 - mse: 0.6237
# Epoch 103/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6157 - mae: 0.5958 - mse: 0.6157
# Epoch 104/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6112 - mae: 0.5942 - mse: 0.6112
# Epoch 105/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6163 - mae: 0.5965 - mse: 0.6163
# Epoch 106/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6010 - mae: 0.5901 - mse: 0.6010
# Epoch 107/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6110 - mae: 0.5961 - mse: 0.6110
# Epoch 108/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6021 - mae: 0.5939 - mse: 0.6021
# Epoch 109/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6022 - mae: 0.5899 - mse: 0.6022
# Epoch 110/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6069 - mae: 0.5921 - mse: 0.6069
# Epoch 111/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6246 - mae: 0.6036 - mse: 0.6246
# Epoch 112/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5952 - mae: 0.5864 - mse: 0.5952
# Epoch 113/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5900 - mae: 0.5845 - mse: 0.5900
# Epoch 114/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5946 - mae: 0.5888 - mse: 0.5946
# Epoch 115/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5759 - mae: 0.5788 - mse: 0.5759
# Epoch 116/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5743 - mae: 0.5779 - mse: 0.5743
# Epoch 117/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5814 - mae: 0.5802 - mse: 0.5814
# Epoch 118/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5634 - mae: 0.5720 - mse: 0.5634
# Epoch 119/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5719 - mae: 0.5758 - mse: 0.5719
# Epoch 120/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5596 - mae: 0.5699 - mse: 0.5596
# Epoch 121/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5533 - mae: 0.5668 - mse: 0.5533
# Epoch 122/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5581 - mae: 0.5684 - mse: 0.5581
# Epoch 123/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5564 - mae: 0.5652 - mse: 0.5564
# Epoch 124/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5510 - mae: 0.5647 - mse: 0.5510
# Epoch 125/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5453 - mae: 0.5616 - mse: 0.5453
# Epoch 126/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5532 - mae: 0.5666 - mse: 0.5532
# Epoch 127/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5611 - mae: 0.5683 - mse: 0.5611
# Epoch 128/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5473 - mae: 0.5619 - mse: 0.5473
# Epoch 129/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5496 - mae: 0.5620 - mse: 0.5496
# Epoch 130/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5430 - mae: 0.5612 - mse: 0.5430
# Epoch 131/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5506 - mae: 0.5657 - mse: 0.5506
# Epoch 132/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5440 - mae: 0.5631 - mse: 0.5440
# Epoch 133/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5566 - mae: 0.5663 - mse: 0.5566
# Epoch 134/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5457 - mae: 0.5590 - mse: 0.5457
# Epoch 135/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5457 - mae: 0.5598 - mse: 0.5457
# Epoch 136/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5406 - mae: 0.5566 - mse: 0.5406
# Epoch 137/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5416 - mae: 0.5588 - mse: 0.5416
# Epoch 138/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5449 - mae: 0.5609 - mse: 0.5449
# Epoch 139/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5665 - mae: 0.5692 - mse: 0.5665
# Epoch 140/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5441 - mae: 0.5648 - mse: 0.5441
# Epoch 141/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5374 - mae: 0.5594 - mse: 0.5374
# Epoch 142/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5394 - mae: 0.5602 - mse: 0.5394
# Epoch 143/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5514 - mae: 0.5632 - mse: 0.5514
# Epoch 144/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1672 - mae: 0.6623 - mse: 1.1672
# Epoch 145/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0221 - mae: 0.7626 - mse: 1.0221
# Epoch 146/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9069 - mae: 0.7137 - mse: 0.9069
# Epoch 147/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8722 - mae: 0.7057 - mse: 0.8722
# Epoch 148/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8507 - mae: 0.6932 - mse: 0.8507
# Epoch 149/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8448 - mae: 0.6910 - mse: 0.8448
# Epoch 150/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8496 - mae: 0.7025 - mse: 0.8496
# Epoch 151/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8370 - mae: 0.6960 - mse: 0.8370
# Epoch 152/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8165 - mae: 0.6861 - mse: 0.8165
# Epoch 153/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8029 - mae: 0.6802 - mse: 0.8029
# Epoch 154/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7896 - mae: 0.6727 - mse: 0.7896
# Epoch 155/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7883 - mae: 0.6714 - mse: 0.7883
# Epoch 156/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7721 - mae: 0.6640 - mse: 0.7721
# Epoch 157/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7588 - mae: 0.6590 - mse: 0.7588
# Epoch 158/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7476 - mae: 0.6529 - mse: 0.7476
# Epoch 159/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7382 - mae: 0.6492 - mse: 0.7382
# Epoch 160/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7329 - mae: 0.6443 - mse: 0.7329
# Epoch 161/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7083 - mae: 0.6371 - mse: 0.7083
# Epoch 162/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7272 - mae: 0.6455 - mse: 0.7272
# Epoch 163/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6958 - mae: 0.6304 - mse: 0.6958
# Epoch 164/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6746 - mae: 0.6215 - mse: 0.6746
# Epoch 165/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6546 - mae: 0.6121 - mse: 0.6546
# Epoch 166/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6541 - mae: 0.6118 - mse: 0.6541
# Epoch 167/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6474 - mae: 0.6088 - mse: 0.6474
# Epoch 168/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6297 - mae: 0.6012 - mse: 0.6297
# Epoch 169/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6261 - mae: 0.6002 - mse: 0.6261
# Epoch 170/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6267 - mae: 0.6013 - mse: 0.6267
# Epoch 171/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6060 - mae: 0.5906 - mse: 0.6060
# Epoch 172/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6000 - mae: 0.5882 - mse: 0.6000
# Epoch 173/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5975 - mae: 0.5878 - mse: 0.5975
# Epoch 174/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5823 - mae: 0.5808 - mse: 0.5823
# Epoch 175/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5743 - mae: 0.5786 - mse: 0.5743
# Epoch 176/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5735 - mae: 0.5780 - mse: 0.5735
# Epoch 177/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5705 - mae: 0.5772 - mse: 0.5705
# Epoch 178/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5602 - mae: 0.5713 - mse: 0.5602
# Epoch 179/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5591 - mae: 0.5720 - mse: 0.5591
# Epoch 180/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5562 - mae: 0.5710 - mse: 0.5562
# Epoch 181/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5538 - mae: 0.5693 - mse: 0.5538
# Epoch 182/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5529 - mae: 0.5696 - mse: 0.5529
# Epoch 183/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5449 - mae: 0.5659 - mse: 0.5449
# Epoch 184/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5469 - mae: 0.5663 - mse: 0.5469
# Epoch 185/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5412 - mae: 0.5633 - mse: 0.5412
# Epoch 186/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5410 - mae: 0.5637 - mse: 0.5410
# Epoch 187/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5359 - mae: 0.5621 - mse: 0.5359
# Epoch 188/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7202 - mae: 0.6419 - mse: 0.7202
# Epoch 189/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6780 - mae: 0.6291 - mse: 0.6780
# Epoch 190/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6247 - mae: 0.6013 - mse: 0.6247
# Epoch 191/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5968 - mae: 0.5917 - mse: 0.5968
# Epoch 192/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5860 - mae: 0.5848 - mse: 0.5860
# Epoch 193/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5748 - mae: 0.5812 - mse: 0.5748
# Epoch 194/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5655 - mae: 0.5751 - mse: 0.5655
# Epoch 195/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5710 - mae: 0.5776 - mse: 0.5710
# Epoch 196/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5657 - mae: 0.5755 - mse: 0.5657
# Epoch 197/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5809 - mae: 0.5831 - mse: 0.5809
# Epoch 198/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5842 - mae: 0.5822 - mse: 0.5842
# Epoch 199/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5438 - mae: 0.5644 - mse: 0.5438
# Epoch 200/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5464 - mae: 0.5667 - mse: 0.5464
# Epoch 201/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5576 - mae: 0.5725 - mse: 0.5576
# Epoch 202/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5296 - mae: 0.5590 - mse: 0.5296
# Epoch 203/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5205 - mae: 0.5537 - mse: 0.5205
# Epoch 204/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5222 - mae: 0.5551 - mse: 0.5222
# Epoch 205/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5229 - mae: 0.5554 - mse: 0.5229
# Epoch 206/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5118 - mae: 0.5490 - mse: 0.5118
# Epoch 207/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5149 - mae: 0.5514 - mse: 0.5149
# Epoch 208/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5130 - mae: 0.5500 - mse: 0.5130
# Epoch 209/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5117 - mae: 0.5493 - mse: 0.5117
# Epoch 210/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5117 - mae: 0.5489 - mse: 0.5117
# Epoch 211/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5115 - mae: 0.5488 - mse: 0.5115
# Epoch 212/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5038 - mae: 0.5431 - mse: 0.5038
# Epoch 213/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4952 - mae: 0.5397 - mse: 0.4952
# Epoch 214/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4919 - mae: 0.5387 - mse: 0.4919
# Epoch 215/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4888 - mae: 0.5374 - mse: 0.4888
# Epoch 216/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4830 - mae: 0.5330 - mse: 0.4830
# Epoch 217/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4766 - mae: 0.5302 - mse: 0.4766
# Epoch 218/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4829 - mae: 0.5345 - mse: 0.4829
# Epoch 219/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4889 - mae: 0.5366 - mse: 0.4889
# Epoch 220/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4780 - mae: 0.5301 - mse: 0.4780
# Epoch 221/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4761 - mae: 0.5286 - mse: 0.4761
# Epoch 222/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4677 - mae: 0.5249 - mse: 0.4677
# Epoch 223/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4797 - mae: 0.5328 - mse: 0.4797
# Epoch 224/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4709 - mae: 0.5270 - mse: 0.4709
# Epoch 225/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4717 - mae: 0.5273 - mse: 0.4717
# Epoch 226/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4856 - mae: 0.5348 - mse: 0.4856
# Epoch 227/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4732 - mae: 0.5291 - mse: 0.4732
# Epoch 228/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4733 - mae: 0.5273 - mse: 0.4733
# Epoch 229/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4706 - mae: 0.5271 - mse: 0.4706
# Epoch 230/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4580 - mae: 0.5198 - mse: 0.4580
# Epoch 231/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4598 - mae: 0.5215 - mse: 0.4598
# Epoch 232/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4580 - mae: 0.5202 - mse: 0.4580
# Epoch 233/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4587 - mae: 0.5226 - mse: 0.4587
# Epoch 234/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4566 - mae: 0.5190 - mse: 0.4566
# Epoch 235/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4624 - mae: 0.5240 - mse: 0.4624
# Epoch 236/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4615 - mae: 0.5203 - mse: 0.4615
# Epoch 237/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4674 - mae: 0.5244 - mse: 0.4674
# Epoch 238/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4441 - mae: 0.5118 - mse: 0.4441
# Epoch 239/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4432 - mae: 0.5133 - mse: 0.4432
# Epoch 240/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4368 - mae: 0.5090 - mse: 0.4368
# Epoch 241/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4329 - mae: 0.5079 - mse: 0.4329
# Epoch 242/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4373 - mae: 0.5092 - mse: 0.4373
# Epoch 243/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4289 - mae: 0.5043 - mse: 0.4289
# Epoch 244/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4255 - mae: 0.5025 - mse: 0.4255
# Epoch 245/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4371 - mae: 0.5078 - mse: 0.4371
# Epoch 246/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4291 - mae: 0.5038 - mse: 0.4291
# Epoch 247/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4358 - mae: 0.5074 - mse: 0.4358
# Epoch 248/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4456 - mae: 0.5120 - mse: 0.4456
# Epoch 249/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4375 - mae: 0.5078 - mse: 0.4375
# Epoch 250/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4175 - mae: 0.4986 - mse: 0.4175
# Epoch 251/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4612 - mae: 0.5197 - mse: 0.4612
# Epoch 252/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4353 - mae: 0.5037 - mse: 0.4353
# Epoch 253/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4200 - mae: 0.4974 - mse: 0.4200
# Epoch 254/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4147 - mae: 0.4957 - mse: 0.4147
# Epoch 255/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4168 - mae: 0.4965 - mse: 0.4168
# Epoch 256/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4129 - mae: 0.4934 - mse: 0.4129
# Epoch 257/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4108 - mae: 0.4939 - mse: 0.4108
# Epoch 258/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4123 - mae: 0.4946 - mse: 0.4123
# Epoch 259/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4130 - mae: 0.4943 - mse: 0.4130
# Epoch 260/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4311 - mae: 0.5039 - mse: 0.4311
# Epoch 261/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4143 - mae: 0.4937 - mse: 0.4143
# Epoch 262/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4104 - mae: 0.4924 - mse: 0.4104
# Epoch 263/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3992 - mae: 0.4853 - mse: 0.3992
# Epoch 264/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4133 - mae: 0.4929 - mse: 0.4133
# Epoch 265/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4148 - mae: 0.4955 - mse: 0.4148
# Epoch 266/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4194 - mae: 0.4975 - mse: 0.4194
# Epoch 267/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4228 - mae: 0.4979 - mse: 0.4228
# Epoch 268/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4377 - mae: 0.5079 - mse: 0.4377
# Epoch 269/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4090 - mae: 0.4918 - mse: 0.4090
# Epoch 270/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4128 - mae: 0.4953 - mse: 0.4128
# Epoch 271/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3971 - mae: 0.4841 - mse: 0.3971
# Epoch 272/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3983 - mae: 0.4844 - mse: 0.3983
# Epoch 273/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3875 - mae: 0.4777 - mse: 0.3875
# Epoch 274/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3996 - mae: 0.4851 - mse: 0.3996
# Epoch 275/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3974 - mae: 0.4843 - mse: 0.3974
# Epoch 276/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3886 - mae: 0.4795 - mse: 0.3886
# Epoch 277/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3974 - mae: 0.4852 - mse: 0.3974
# Epoch 278/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4082 - mae: 0.4907 - mse: 0.4082
# Epoch 279/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4335 - mae: 0.5020 - mse: 0.4335
# Epoch 280/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3935 - mae: 0.4813 - mse: 0.3935
# Epoch 281/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3973 - mae: 0.4819 - mse: 0.3973
# Epoch 282/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3917 - mae: 0.4821 - mse: 0.3917
# Epoch 283/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3943 - mae: 0.4822 - mse: 0.3943
# Epoch 284/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3888 - mae: 0.4780 - mse: 0.3888
# Epoch 285/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3926 - mae: 0.4801 - mse: 0.3926
# Epoch 286/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3811 - mae: 0.4732 - mse: 0.3811
# Epoch 287/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3924 - mae: 0.4802 - mse: 0.3924
# Epoch 288/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3902 - mae: 0.4791 - mse: 0.3902
# Epoch 289/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4359 - mae: 0.5052 - mse: 0.4359
# Epoch 290/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4357 - mae: 0.5048 - mse: 0.4357
# Epoch 291/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4120 - mae: 0.4893 - mse: 0.4120
# Epoch 292/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3905 - mae: 0.4789 - mse: 0.3905
# Epoch 293/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3864 - mae: 0.4763 - mse: 0.3864
# Epoch 294/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3807 - mae: 0.4722 - mse: 0.3807
# Epoch 295/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3858 - mae: 0.4771 - mse: 0.3858
# Epoch 296/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4572 - mae: 0.5140 - mse: 0.4572
# Epoch 297/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3944 - mae: 0.4848 - mse: 0.3944
# Epoch 298/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3750 - mae: 0.4652 - mse: 0.3750
# Epoch 299/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3665 - mae: 0.4640 - mse: 0.3665
# Epoch 300/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3615 - mae: 0.4621 - mse: 0.3615
# Epoch 301/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3548 - mae: 0.4557 - mse: 0.3548
# Epoch 302/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3809 - mae: 0.4709 - mse: 0.3809
# Epoch 303/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4177 - mae: 0.4949 - mse: 0.4177
# Epoch 304/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3801 - mae: 0.4726 - mse: 0.3801
# Epoch 305/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3582 - mae: 0.4581 - mse: 0.3582
# Epoch 306/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3612 - mae: 0.4584 - mse: 0.3612
# Epoch 307/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3600 - mae: 0.4593 - mse: 0.3600
# Epoch 308/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4361 - mae: 0.4948 - mse: 0.4361
# Epoch 309/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4288 - mae: 0.5005 - mse: 0.4288
# Epoch 310/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4279 - mae: 0.4977 - mse: 0.4279
# Epoch 311/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3996 - mae: 0.4844 - mse: 0.3996
# Epoch 312/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3995 - mae: 0.4836 - mse: 0.3995
# Epoch 313/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4103 - mae: 0.4903 - mse: 0.4103
# Epoch 314/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4318 - mae: 0.4997 - mse: 0.4318
# Epoch 315/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3779 - mae: 0.4700 - mse: 0.3779
# Epoch 316/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3661 - mae: 0.4637 - mse: 0.3661
# Epoch 317/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3512 - mae: 0.4525 - mse: 0.3512
# Epoch 318/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3403 - mae: 0.4450 - mse: 0.3403
# Epoch 319/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3380 - mae: 0.4431 - mse: 0.3380
# Epoch 320/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3369 - mae: 0.4422 - mse: 0.3369
# Epoch 321/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3484 - mae: 0.4501 - mse: 0.3484
# Epoch 322/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3286 - mae: 0.4383 - mse: 0.3286
# Epoch 323/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3233 - mae: 0.4335 - mse: 0.3233
# Epoch 324/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3207 - mae: 0.4315 - mse: 0.3207
# Epoch 325/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3208 - mae: 0.4325 - mse: 0.3208
# Epoch 326/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3258 - mae: 0.4335 - mse: 0.3258
# Epoch 327/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3180 - mae: 0.4292 - mse: 0.3180
# Epoch 328/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3244 - mae: 0.4320 - mse: 0.3244
# Epoch 329/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3138 - mae: 0.4265 - mse: 0.3138
# Epoch 330/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3172 - mae: 0.4295 - mse: 0.3172
# Epoch 331/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3145 - mae: 0.4294 - mse: 0.3145
# Epoch 332/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3143 - mae: 0.4296 - mse: 0.3143
# Epoch 333/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3189 - mae: 0.4311 - mse: 0.3189
# Epoch 334/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3151 - mae: 0.4291 - mse: 0.3151
# Epoch 335/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3147 - mae: 0.4297 - mse: 0.3147
# Epoch 336/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3096 - mae: 0.4238 - mse: 0.3096
# Epoch 337/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2981 - mae: 0.4166 - mse: 0.2981
# Epoch 338/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2996 - mae: 0.4172 - mse: 0.2996
# Epoch 339/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2906 - mae: 0.4114 - mse: 0.2906
# Epoch 340/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3060 - mae: 0.4202 - mse: 0.3060
# Epoch 341/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3261 - mae: 0.4343 - mse: 0.3261
# Epoch 342/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3340 - mae: 0.4370 - mse: 0.3340
# Epoch 343/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3401 - mae: 0.4340 - mse: 0.3401
# Epoch 344/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3040 - mae: 0.4223 - mse: 0.3040
# Epoch 345/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3053 - mae: 0.4241 - mse: 0.3053
# Epoch 346/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3089 - mae: 0.4238 - mse: 0.3089
# Epoch 347/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3014 - mae: 0.4185 - mse: 0.3014
# Epoch 348/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2936 - mae: 0.4140 - mse: 0.2936
# Epoch 349/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2979 - mae: 0.4162 - mse: 0.2979
# Epoch 350/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3144 - mae: 0.4269 - mse: 0.3144
# Epoch 351/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3072 - mae: 0.4214 - mse: 0.3072
# Epoch 352/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3330 - mae: 0.4381 - mse: 0.3330
# Epoch 353/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3154 - mae: 0.4291 - mse: 0.3154
# Epoch 354/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2969 - mae: 0.4162 - mse: 0.2969
# Epoch 355/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3013 - mae: 0.4170 - mse: 0.3013
# Epoch 356/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3094 - mae: 0.4243 - mse: 0.3094
# Epoch 357/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3116 - mae: 0.4234 - mse: 0.3116
# Epoch 358/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3206 - mae: 0.4316 - mse: 0.3206
# Epoch 359/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3150 - mae: 0.4275 - mse: 0.3150
# Epoch 360/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3023 - mae: 0.4199 - mse: 0.3023
# Epoch 361/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3009 - mae: 0.4184 - mse: 0.3009
# Epoch 362/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8912 - mae: 0.5916 - mse: 0.8912
# Epoch 363/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9822 - mae: 0.7489 - mse: 0.9822
# Epoch 364/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8646 - mae: 0.7009 - mse: 0.8646
# Epoch 365/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7229 - mae: 0.6388 - mse: 0.7229
# Epoch 366/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6172 - mae: 0.5953 - mse: 0.6172
# Epoch 367/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5562 - mae: 0.5679 - mse: 0.5562
# Epoch 368/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5062 - mae: 0.5418 - mse: 0.5062
# Epoch 369/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4848 - mae: 0.5290 - mse: 0.4848
# Epoch 370/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4620 - mae: 0.5174 - mse: 0.4620
# Epoch 371/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4295 - mae: 0.5004 - mse: 0.4295
# Epoch 372/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4174 - mae: 0.4936 - mse: 0.4174
# Epoch 373/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4021 - mae: 0.4866 - mse: 0.4021
# Epoch 374/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3989 - mae: 0.4851 - mse: 0.3989
# Epoch 375/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4109 - mae: 0.4896 - mse: 0.4109
# Epoch 376/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3873 - mae: 0.4761 - mse: 0.3873
# Epoch 377/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3826 - mae: 0.4748 - mse: 0.3826
# Epoch 378/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3790 - mae: 0.4722 - mse: 0.3790
# Epoch 379/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3768 - mae: 0.4722 - mse: 0.3768
# Epoch 380/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3625 - mae: 0.4623 - mse: 0.3625
# Epoch 381/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3425 - mae: 0.4500 - mse: 0.3425
# Epoch 382/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3608 - mae: 0.4612 - mse: 0.3608
# Epoch 383/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3357 - mae: 0.4448 - mse: 0.3357
# Epoch 384/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3267 - mae: 0.4397 - mse: 0.3267
# Epoch 385/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3222 - mae: 0.4355 - mse: 0.3222
# Epoch 386/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3227 - mae: 0.4380 - mse: 0.3227
# Epoch 387/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3248 - mae: 0.4372 - mse: 0.3248
# Epoch 388/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3281 - mae: 0.4408 - mse: 0.3281
# Epoch 389/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3271 - mae: 0.4401 - mse: 0.3271
# Epoch 390/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3806 - mae: 0.4756 - mse: 0.3806
# Epoch 391/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4767 - mae: 0.5224 - mse: 0.4767
# Epoch 392/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4456 - mae: 0.5108 - mse: 0.4456
# Epoch 393/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3952 - mae: 0.4822 - mse: 0.3952
# Epoch 394/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3629 - mae: 0.4637 - mse: 0.3629
# Epoch 395/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.3481 - mae: 0.4525 - mse: 0.3481
# Epoch 396/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3831 - mae: 0.4731 - mse: 0.3831
# Epoch 397/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3450 - mae: 0.4507 - mse: 0.3450
# Epoch 398/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3123 - mae: 0.4300 - mse: 0.3123
# Epoch 399/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3006 - mae: 0.4204 - mse: 0.3006
# Epoch 400/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3135 - mae: 0.4277 - mse: 0.3135
# Epoch 401/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2977 - mae: 0.4172 - mse: 0.2977
# Epoch 402/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2865 - mae: 0.4101 - mse: 0.2865
# Epoch 403/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2691 - mae: 0.3987 - mse: 0.2691
# Epoch 404/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2715 - mae: 0.4007 - mse: 0.2715
# Epoch 405/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2639 - mae: 0.3939 - mse: 0.2639
# Epoch 406/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2701 - mae: 0.4007 - mse: 0.2701
# Epoch 407/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2621 - mae: 0.3940 - mse: 0.2621
# Epoch 408/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2576 - mae: 0.3883 - mse: 0.2576
# Epoch 409/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2551 - mae: 0.3869 - mse: 0.2551
# Epoch 410/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2428 - mae: 0.3774 - mse: 0.2428
# Epoch 411/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2389 - mae: 0.3756 - mse: 0.2389
# Epoch 412/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2415 - mae: 0.3768 - mse: 0.2415
# Epoch 413/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2548 - mae: 0.3894 - mse: 0.2548
# Epoch 414/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2520 - mae: 0.3876 - mse: 0.2520
# Epoch 415/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2517 - mae: 0.3852 - mse: 0.2517
# Epoch 416/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2676 - mae: 0.3972 - mse: 0.2676
# Epoch 417/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2815 - mae: 0.4083 - mse: 0.2815
# Epoch 418/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2800 - mae: 0.4054 - mse: 0.2800
# Epoch 419/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3006 - mae: 0.4217 - mse: 0.3006
# Epoch 420/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2976 - mae: 0.4224 - mse: 0.2976
# Epoch 421/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3011 - mae: 0.4225 - mse: 0.3011
# Epoch 422/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2974 - mae: 0.4180 - mse: 0.2974
# Epoch 423/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4077 - mae: 0.4480 - mse: 0.4077
# Epoch 424/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8955 - mae: 0.7034 - mse: 0.8955
# Epoch 425/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8598 - mae: 0.6885 - mse: 0.8598
# Epoch 426/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6568 - mae: 0.6078 - mse: 0.6568
# Epoch 427/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5634 - mae: 0.5689 - mse: 0.5634
# Epoch 428/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5146 - mae: 0.5442 - mse: 0.5146
# Epoch 429/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5642 - mae: 0.5668 - mse: 0.5642
# Epoch 430/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5127 - mae: 0.5430 - mse: 0.5127
# Epoch 431/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4754 - mae: 0.5259 - mse: 0.4754
# Epoch 432/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4173 - mae: 0.4944 - mse: 0.4173
# Epoch 433/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3915 - mae: 0.4764 - mse: 0.3915
# Epoch 434/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3744 - mae: 0.4702 - mse: 0.3744
# Epoch 435/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3588 - mae: 0.4585 - mse: 0.3588
# Epoch 436/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3426 - mae: 0.4500 - mse: 0.3426
# Epoch 437/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3260 - mae: 0.4377 - mse: 0.3260
# Epoch 438/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3150 - mae: 0.4311 - mse: 0.3150
# Epoch 439/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3143 - mae: 0.4288 - mse: 0.3143
# Epoch 440/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3020 - mae: 0.4227 - mse: 0.3020
# Epoch 441/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3052 - mae: 0.4249 - mse: 0.3052
# Epoch 442/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3165 - mae: 0.4334 - mse: 0.3165
# Epoch 443/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3841 - mae: 0.4507 - mse: 0.3841
# Epoch 444/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0749 - mae: 0.7749 - mse: 1.0749
# Epoch 445/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9667 - mae: 0.7458 - mse: 0.9667
# Epoch 446/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9669 - mae: 0.7460 - mse: 0.9669
# Epoch 447/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9658 - mae: 0.7462 - mse: 0.9658
# Epoch 448/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9645 - mae: 0.7453 - mse: 0.9645
# Epoch 449/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9639 - mae: 0.7450 - mse: 0.9639
# Epoch 450/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9624 - mae: 0.7443 - mse: 0.9624
# Epoch 451/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9624 - mae: 0.7447 - mse: 0.9624
# Epoch 452/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9619 - mae: 0.7441 - mse: 0.9619
# Epoch 453/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9604 - mae: 0.7440 - mse: 0.9604
# Epoch 454/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9601 - mae: 0.7440 - mse: 0.9601
# Epoch 455/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9589 - mae: 0.7433 - mse: 0.9589
# Epoch 456/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9594 - mae: 0.7438 - mse: 0.9594
# Epoch 457/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9595 - mae: 0.7437 - mse: 0.9595
# Epoch 458/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9592 - mae: 0.7435 - mse: 0.9592
# Epoch 459/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9610 - mae: 0.7449 - mse: 0.9610
# Epoch 460/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9566 - mae: 0.7430 - mse: 0.9566
# Epoch 461/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9547 - mae: 0.7428 - mse: 0.9547
# Epoch 462/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9578 - mae: 0.7438 - mse: 0.9578
# Epoch 463/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9554 - mae: 0.7420 - mse: 0.9554
# Epoch 464/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9534 - mae: 0.7411 - mse: 0.9534
# Epoch 465/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9575 - mae: 0.7429 - mse: 0.9575
# Epoch 466/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9525 - mae: 0.7402 - mse: 0.9525
# Epoch 467/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9523 - mae: 0.7410 - mse: 0.9523
# Epoch 468/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9537 - mae: 0.7426 - mse: 0.9537
# Epoch 469/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9518 - mae: 0.7416 - mse: 0.9518
# Epoch 470/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9659 - mae: 0.7459 - mse: 0.9659
# Epoch 471/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9534 - mae: 0.7416 - mse: 0.9534
# Epoch 472/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9464 - mae: 0.7380 - mse: 0.9464
# Epoch 473/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9440 - mae: 0.7373 - mse: 0.9440
# Epoch 474/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9413 - mae: 0.7359 - mse: 0.9413
# Epoch 475/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9395 - mae: 0.7343 - mse: 0.9395
# Epoch 476/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9375 - mae: 0.7331 - mse: 0.9375
# Epoch 477/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9377 - mae: 0.7336 - mse: 0.9377
# Epoch 478/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9405 - mae: 0.7352 - mse: 0.9405
# Epoch 479/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9430 - mae: 0.7366 - mse: 0.9430
# Epoch 480/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9378 - mae: 0.7345 - mse: 0.9378
# Epoch 481/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9313 - mae: 0.7306 - mse: 0.9313
# Epoch 482/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9291 - mae: 0.7300 - mse: 0.9291
# Epoch 483/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9276 - mae: 0.7284 - mse: 0.9276
# Epoch 484/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9264 - mae: 0.7282 - mse: 0.9264
# Epoch 485/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9279 - mae: 0.7292 - mse: 0.9279
# Epoch 486/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9251 - mae: 0.7277 - mse: 0.9251
# Epoch 487/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9268 - mae: 0.7286 - mse: 0.9268
# Epoch 488/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9248 - mae: 0.7282 - mse: 0.9248
# Epoch 489/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9192 - mae: 0.7261 - mse: 0.9192
# Epoch 490/1000
# ...
# Epoch 856/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 857/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 858/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 859/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 860/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7478 - mse: 0.9771
# Epoch 861/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# Epoch 862/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7481 - mse: 0.9772
# Epoch 863/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7489 - mse: 0.9772
# Epoch 864/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9774 - mae: 0.7491 - mse: 0.9774
# Epoch 865/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9776 - mae: 0.7483 - mse: 0.9776
# Epoch 866/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9775 - mae: 0.7481 - mse: 0.9775
# Epoch 867/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9773 - mae: 0.7487 - mse: 0.9773
# Epoch 868/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9774 - mae: 0.7481 - mse: 0.9774
# Epoch 869/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9773 - mae: 0.7488 - mse: 0.9773
# Epoch 870/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 871/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 872/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 873/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 874/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 875/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 876/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 877/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7478 - mse: 0.9771
# Epoch 878/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 879/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 880/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 881/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7479 - mse: 0.9771
# Epoch 882/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 883/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 884/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 885/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 886/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 887/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 888/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 889/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 890/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 891/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 892/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 893/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7485 - mse: 0.9772
# Epoch 894/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 895/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7487 - mse: 0.9772
# Epoch 896/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7479 - mse: 0.9771
# Epoch 897/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 898/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7484 - mse: 0.9771
# Epoch 899/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 900/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 901/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 902/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 903/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 904/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 905/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 906/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 907/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 908/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 909/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 910/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# Epoch 911/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7476 - mse: 0.9771
# Epoch 912/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 913/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 914/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 915/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 916/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7484 - mse: 0.9771
# Epoch 917/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# Epoch 918/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7478 - mse: 0.9771
# Epoch 919/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 920/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7489 - mse: 0.9772
# Epoch 921/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7479 - mse: 0.9772
# Epoch 922/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 923/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# Epoch 924/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9773 - mae: 0.7487 - mse: 0.9773
# Epoch 925/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7478 - mse: 0.9772
# Epoch 926/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 927/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 928/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 929/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7486 - mse: 0.9771
# Epoch 930/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 931/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7486 - mse: 0.9771
# Epoch 932/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 933/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 934/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 935/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 936/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 937/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 938/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 939/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 940/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7479 - mse: 0.9771
# Epoch 941/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 942/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 943/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 944/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7489 - mse: 0.9772
# Epoch 945/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7481 - mse: 0.9772
# Epoch 946/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9773 - mae: 0.7490 - mse: 0.9773
# Epoch 947/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9771 - mae: 0.7478 - mse: 0.9771
# Epoch 948/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 949/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 950/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7484 - mse: 0.9771
# Epoch 951/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 952/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7485 - mse: 0.9772
# Epoch 953/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7479 - mse: 0.9771
# Epoch 954/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7487 - mse: 0.9772
# Epoch 955/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 956/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7487 - mse: 0.9772
# Epoch 957/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 958/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 959/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 960/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 961/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 962/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9772 - mae: 0.7485 - mse: 0.9772
# Epoch 963/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 964/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 965/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 966/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 967/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7485 - mse: 0.9772
# Epoch 968/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 969/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 970/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 971/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 972/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 973/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7486 - mse: 0.9771
# Epoch 974/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7482 - mse: 0.9771
# Epoch 975/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7486 - mse: 0.9772
# Epoch 976/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7479 - mse: 0.9771
# Epoch 977/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# Epoch 978/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7478 - mse: 0.9771
# Epoch 979/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7487 - mse: 0.9772
# Epoch 980/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 981/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9772 - mae: 0.7487 - mse: 0.9772
# Epoch 982/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 983/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7484 - mse: 0.9771
# Epoch 984/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 985/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 986/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 987/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 988/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7483 - mse: 0.9771
# Epoch 989/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7481 - mse: 0.9771
# Epoch 990/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9771 - mae: 0.7485 - mse: 0.9771
# Epoch 991/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 992/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 993/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7484 - mse: 0.9772
# Epoch 994/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9773 - mae: 0.7487 - mse: 0.9773
# Epoch 995/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9772 - mae: 0.7483 - mse: 0.9772
# Epoch 996/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9774 - mae: 0.7484 - mse: 0.9774
# Epoch 997/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9774 - mae: 0.7479 - mse: 0.9774
# Epoch 998/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9773 - mae: 0.7493 - mse: 0.9773
# Epoch 999/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9771 - mae: 0.7480 - mse: 0.9771
# Epoch 1000/1000
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9772 - mae: 0.7488 - mse: 0.9772
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 33
#      31 #save model
#      32 fn = identity + str(fold_no) + '_' + sampling_type
# ---> 33 model.save_weights('../../data/benchmark-models/chkpts/%s.chkpt' % fn)
#      35 y_hat = experimental_setup.scaler.inverse_transform(model.predict(x_test))
#      37 results = pd.DataFrame({
#      38     'smiles': smiles_test.flatten(),
#      39     'prediction_neglogld50': y_hat.flatten(),
#    (...)
#      44     'actual_epa': converter.convert_to_epa(y_test, smiles_test),
#      45 })
#
# File c:\Users\3742\anaconda3\envs\ai4pfas\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\3742\anaconda3\envs\ai4pfas\Lib\site-packages\keras\src\saving\saving_api.py:222, in save_weights(model, filepath, overwrite, **kwargs)
#     219 @keras_export("keras.saving.save_weights")
#     220 def save_weights(model, filepath, overwrite=True, **kwargs):
#     221     if not str(filepath).endswith(".weights.h5"):
# --> 222         raise ValueError(
#     223             "The filename must end in `.weights.h5`. "
#     224             f"Received: filepath={filepath}"
#     225         )
#     226     try:
#     227         exists = os.path.exists(filepath)
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=../../data/benchmark-models/chkpts/dnn_mordred0_random.chkpt

# %% [markdown]
# # Results comparison

# %%
#from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
#import pandas as pd
#import numpy as np

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np  # Ensure numpy is imported

compare_benchmarks = ['rf_mordred', 'rf_ecfp', 'rf_nmf_ecfp', 'dnn_mordred', 'dnn_ecfp', 'gp', 'gcn'] 

aggregated = pd.DataFrame(columns=['benchmark', 'fold_no', 'r2', 'mae', 'rmse', 'accuracy'])  # Adding fold_no column

for identity in compare_benchmarks:
    benchmark = _benchmarks[identity]
    folds = enumerate(kfold.get_folds(benchmark['encoding']))

    for fold_no, data in folds:
        fn = identity + str(fold_no) + '_' + sampling_type
        validation = pd.read_csv(f'../../data/benchmark-models/{fn}_predictions.csv')
        
        # Adding fold_no and metrics calculations
        aggregated = aggregated.append({
            'benchmark': identity,
            'fold_no': fold_no,
            'r2': r2_score(validation['actual_neglogld50'], validation['prediction_neglogld50']),
            'mae': mean_absolute_error(validation['actual_neglogld50'], validation['prediction_neglogld50']),
            'rmse': mean_squared_error(validation['actual_neglogld50'], validation['prediction_neglogld50'], squared=False),
            'accuracy': np.sum(validation['actual_epa'] == validation['prediction_epa']) / len(validation)
        }, ignore_index=True)

print(aggregated)


'''  
compare_benchmarks = ['rf_mordred','rf_ecfp','rf_nmf_ecfp','dnn_mordred','dnn_ecfp','gp','gcn'] 

aggregated = pd.DataFrame(columns=['benchmark', 'fold_no', 'r2', 'mae', 'rmse', 'accuracy'])  # Adding fold_no column
aggregated = pd.DataFrame()
#aggregated = pd.DataFrame(columns=['benchmark', 'r2', 'mae', 'rmse', 'accuracy'])  #DU added

for identity in compare_benchmarks:
        
    benchmark = _benchmarks[identity]
    folds = enumerate(kfold.get_folds(benchmark['encoding']))
    
    
    for fold_no, data in folds:
        fn = identity + str(fold_no) + '_' + sampling_type
        
        validation = pd.read_csv('../../data/benchmark-models/%s_predictions.csv' % fn)
        
        print(validation)
        aggregated = aggregated.extend()
        pass
        
        aggregated = aggregated.append({
            'benchmark': identity,
            'r2': r2_score(validation['actual_neglogld50'], validation['prediction_neglogld50']),
            'mae': mean_absolute_error(validation['actual_neglogld50'], validation['prediction_neglogld50']),
            'rmse': mean_squared_error(validation['actual_neglogld50'], validation['prediction_neglogld50'], squared=False),
            'accuracy': np.sum(validation['actual_epa'] == validation['prediction_epa']) / len(validation)
        }, ignore_index=True)


'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7152\346946299.py in ?()
#      18         fn = identity + str(fold_no) + '_' + sampling_type
#      19         validation = pd.read_csv(f'../../data/benchmark-models/{fn}_predictions.csv')
#      20
#      21         # Adding fold_no and metrics calculations
# ---> 22         aggregated = aggregated.append({
#      23             'benchmark': identity,
#      24             'fold_no': fold_no,
#      25             'r2': r2_score(validation['actual_neglogld50'], validation['prediction_neglogld50']),
#
# c:\Users\3742\anaconda3\envs\ai4pfas\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
aggregated.pivot_table(index='benchmark', aggfunc=np.mean)
